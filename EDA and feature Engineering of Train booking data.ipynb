# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train_booking_data_.csv')
data
# Out:
#     Booking ID  User Age Preferred Age Group  Seat Number  Row  Column  \
# 0            1        23               18-25           12    2       6
# 1            2        34               25-40           32    6       2
# 2            3        45               40-60           88   15       4
# 3            4        62                 60+           92   16       2
# 4            5        29               25-40           41    7       5
# 5            6        40               40-60           72   12       6
# 6            7        58                 60+           94   16       4
# 7            8        31               25-40           45    8       3
# 8            9        22               18-25           19    4       1
# 9           10        38               25-40           34    6       4
# 10          11        27               18-25           16    3       4
# 11          12        50               40-60           79   14       1
# 12          13        41               40-60           64   11       4
# 13          14        63                 60+           98   17       2
# 14          15        36               25-40           52    9       4
# 15          16        52               40-60           81   14       3
# 16          17        29               25-40           53    9       5
# 17          18        47               40-60           73   13       1
# 18          19        61                 60+           97   17       1
# 19          20        33               25-40           49   10       2
# 20          21        52               40-60           67   12       1
# 21          22        19               18-25            8    2       2
# 22          23        41               40-60           68   12       2
# 23          24        25               18-25            6    1       6
#
#    Seat Type  Seat Booked
# 0     Window         True
# 1     Middle         True
# 2      Aisle         True
# 3     Middle         True
# 4     Middle         True
# 5     Window         True
# 6      Aisle         True
# 7      Aisle         True
# 8     Window         True
# 9      Aisle         True
# 10     Aisle         True
# 11    Window         True
# 12     Aisle         True
# 13    Middle         True
# 14     Aisle         True
# 15     Aisle         True
# 16    Middle         True
# 17    Window         True
# 18    Window         True
# 19    Middle         True
# 20    Window         True
# 21    Middle         True
# 22    Middle         True
# 23    Window         True

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['User Age'], kde=True, bins=10)
plt.title('Distribution of User Age')
plt.show()

plt.figure(figsize=(8, 5))
sns.countplot(x='Seat Type', data=data)
plt.title('Seat Type Preferences')
plt.show()

plt.figure(figsize=(8, 5))
sns.countplot(x='Seat Type', hue='Seat Booked', data=data)
plt.title('Booking Status by Seat Type')
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x='Row', y='Column', hue='Seat Booked', data=data)
plt.title('Seat Location (Row vs Column) and Booking Status')
plt.show()

plt.figure(figsize=(8, 5))
sns.countplot(x='Preferred Age Group', hue='Seat Type', data=data)
plt.title('Age Group vs Seat Type Preferences')
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\PRAMANGSHU\AppData\Local\Temp\ipykernel_2732\2044585588.py:27: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap='coolwarm')

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)

data['Preferred Age Group'] = data['Preferred Age Group'].astype('category').cat.codes
data['Seat Type'] = data['Seat Type'].astype('category').cat.codes
# Out:
# Missing Values:
#  Booking ID             0
# User Age               0
# Preferred Age Group    0
# Seat Number            0
# Row                    0
# Column                 0
# Seat Type              0
# Seat Booked            0
# dtype: int64
